# %%
# !pwd
# Out:
# /content/gdrive/My Drive/TestingGitCloneIntoGoogleDrive/IntegratingClonedGithubRepoWithGoogleColabAndGithubControl

# %%
#INPUTS

#repoPath should start with the path 
#'/content/gdrive/My Drive/' and go to the folder where the git repo is, and should end with the name of the repo:
repoPath = '/content/gdrive/My Drive/TestingGitCloneIntoGoogleDrive/findingKeyphraseUsingTextRank'
userEmail = 'sanmesh1@gmail.com'
userName = 'sanmesh1'

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import os
os.chdir(repoPath)
#%cd gdrive/My Drive/project_folder/TextSimilarityUsingWord2Vec

# %%
# !git config --global user.email $userEmail
#!git config --global user.name "sanmeshkumar udhayakumar"
# !git config --global user.name $userName

# %%
# !git pull
# Out:
# Already up to date.

# %%
# !git add .
# !git commit -m "cleaned up the wmd code"
# !git push
# Out:
# [master 9dfe95a] cleaned up the wmd code
#  2 files changed, 2 insertions(+), 2 deletions(-)
#  rewrite GitCommands.ipynb (69%)
#  rewrite itemSimilarityWithWMD.ipynb (71%)
# Counting objects: 4, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 1.31 KiB | 671.00 KiB/s, done.
# Total 4 (delta 3), reused 0 (delta 0)
# remote: Resolving deltas: 100% (3/3), completed with 3 local objects.
# To https://github.com/sanmesh1/textSimilarityUsingWordMoversDistance.git
#    dffd1cb..9dfe95a  master -> master
